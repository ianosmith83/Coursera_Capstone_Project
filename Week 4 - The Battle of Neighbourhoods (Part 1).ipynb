# %% [markdown]
# # Segmenting and clustering neighbourhoods in Chicago

# %% [markdown]
# ## Data Science Capstone - Week 4 Graded Assignment

# %% [markdown]
# ### Start by importing the relevant libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import requests
from PIL import Image, ImageDraw
print('Libraries imported!')
# Out:
# Libraries imported!

# %%
url = 'https://media.timeout.com/images/105383118/1024/576/image.jpg'

im = Image.open(requests.get(url,stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1023x576 at 0x7F8373E159B0>

# %% [markdown]
# ## A description of the problem
#
# Chicago is one of the largest cities in the US. With a population of over 2.7 million as of 2017 it is a hugely important cultural and economic hub in the US. It also boasts one of the largest crime rates in the US. I will be attempting to perform analysis on Chicago crime data for the year 2017.
#
# As the city grows and develops, it becomes increasingly important to examine and understand it quantitiatively.
#
# Some key questions that I would like to answer are:
#
# 1. What are the areas with the highest amount of crime in Chicago?
#
# 2. Using Foursquare data, what venues are most common in different locations within the city?
#
# Developers and people looking to move to the city would be interested in the above questions. Naturally people would like to avoid areas of high crime and certain people would like to know what anemities are in the area they will be moving to.
#
# ### Data
#
# The data sources that I will be making use of for this project:
#
# 1. Chicago Crime Data - https://www.kaggle.com/currie32/crimes-in-chicago
#
# 2. Foursquare for location access - https://foursquare.com/
#
# Using the above datasets will allow us to answer the questions. The Chicago crime data will allow us to see what neighbourhoods have the most crime and the foursquare location data will allow us to visualise the venues that are most common in different locations around the city.
